# %%
# !wget -O /content/bestv8.pt "https://drive.google.com/uc?export=download&id=1T8Wh2F9-kiQ8vBNlPTOr-bz-k5FyGiKh"
# Out:
# --2024-06-12 18:43:51--  https://drive.google.com/uc?export=download&id=1T8Wh2F9-kiQ8vBNlPTOr-bz-k5FyGiKh
# Resolving drive.google.com (drive.google.com)... 74.125.141.113, 74.125.141.138, 74.125.141.100, ...
# Connecting to drive.google.com (drive.google.com)|74.125.141.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1T8Wh2F9-kiQ8vBNlPTOr-bz-k5FyGiKh&export=download [following]
# --2024-06-12 18:43:51--  https://drive.usercontent.google.com/download?id=1T8Wh2F9-kiQ8vBNlPTOr-bz-k5FyGiKh&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.139.132, 2607:f8b0:400c:c05::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.139.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22554841 (22M) [application/octet-stream]
# Saving to: ‘/content/bestv8.pt’
#
# ...

# %% [markdown]
# # **YOLO V8 Custom Image**

# %%
# !git clone https://github.com/ultralytics/ultralytics.git

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()


from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/107.7 GB disk)

# %%
import os
from IPython.display import Image, display



model_path = os.path.join(os.getenv("HOME"), "/content/bestv8.pt")
image_path = "/content/djj.jpg"  



# !yolo task=detect mode=predict model={model_path} source={image_path} save=True



output_image_path = os.path.join(os.getcwd(), "/content/runs/detect/predict7", os.path.basename(image_path))
display(Image(filename=output_image_path))
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/djj.jpg: 800x800 55 Buildings, 1 Field, 3 Free spaces, 11 Greenerys, 11 Roadss, 6 Solar-Panels, 18 Tin-shed-Houses, 1 Water, 1356.5ms
# Speed: 33.7ms preprocess, 1356.5ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %%capture cap --no-stderr
import os
from IPython.display import Image, display


model_path = os.path.join(os.getenv("HOME"), "/content/bestv8.pt")
image_path = "/content/djj.jpg"  


# !yolo task=detect mode=predict model={model_path} source={image_path} save=True


output_text_path = os.path.join(output_dir, "output.txt")
with open(output_text_path, 'w') as f:
    f.write(cap.stdout)


output_image_path = os.path.join(os.getcwd(), "/content/runs/detect/predict7", os.path.basename(image_path))
display(Image(filename=output_image_path))

# %%
output_image_path = os.path.join(os.getcwd(), "/content/runs/detect/predict9", os.path.basename(image_path))
display(Image(filename=output_image_path))

# %%
# %%capture cap --no-stderr
# Path to the trained model and the image
model_path = os.path.join(os.getenv("HOME"), "/content/bestv8.pt")
image_path = "/content/djj.jpg"  # Change this to the path of your custom photo

# Command to perform detection
# !yolo task=detect mode=predict model="{model_path}" source="{image_path}" save=True

# Assuming the output is saved in a directory named predict7
output_dir = "/content/runs/detect/predict3"

# Write output to a text file
output_text_path = os.path.join(output_dir, "output.txt")
with open(output_text_path, 'w') as f:
    f.write(cap.stdout)

# Display the output image
output_image_path = os.path.join(output_dir, os.path.basename(image_path))
display(Image(filename=output_image_path))

print(f"Detection results saved to {output_text_path}")

# %%
def extract_image_info(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('image 1/1'):
                return line
    return None
def parse_buildings(image_info):
    # This regex extracts the number of buildings from the line
    import re
    match = re.search(r"(\d+) Buildings", image_info)
    if match:
        return int(match.group(1))
    return 0

def categorize_environment(buildings_count):
    urban_threshold = 50  # More than 50 buildings means urban
    if buildings_count > urban_threshold:
        return "Urban"
    return "Rural"
# Path to the output file
output_file_path = "/content/runs/detect/predict3/output.txt"

# Extract the relevant image info
image_info = extract_image_info(output_file_path)
if image_info:
    buildings_count = parse_buildings(image_info)
    category = categorize_environment(buildings_count)
    print(f"Environment is categorized as: {category}")
else:
    print("No image info found.")
# Out:
# Environment is categorized as: Urban
